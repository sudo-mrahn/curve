# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import genscore
import curve as cv
import show

# %%
# # unimodal (normal) distribution
# # I think this is the least realistic
# n, mean, sd = 4000, 80, 12
# test = genscore.unimodal(n,mean,sd)

# %%
# # uniform distribution
# # also pretty unrealistic
# n = 400
# test = genscore.uniform(n)

# %%
# the gamma distribution
n, shape, scale = int(2e4), 2.05, 10
gamma = genscore.standard(n, shape, scale)

# %%
# bimodal distribution
# as sum of two normal distributions 
n, p, mod_1, mod_2, sd_1, sd_2 = 2e4, 0.7, 90, 70, 5, 12
bimod = genscore.bimodal(n,p,mod_1,mod_2,sd_1,sd_2)

# %%
# trimodal distribution
# Most similar to P5 final exam:
n,p_1,p_2,mod_1,mod_2,mod_3,sd_1,sd_2,sd_3 = 2e6, 0.33, 0.4, 92, 75, 50, 2, 6, 15
trimod = genscore.trimodal(n,p_1,p_2,mod_1,mod_2,mod_3,sd_1,sd_2,sd_3)

# %%
show.compare4(
    trimod, 
    cv.floor(trimod, 50), 
    cv.scalemax(trimod, 50), 
    cv.scalemed(trimod, 50))
